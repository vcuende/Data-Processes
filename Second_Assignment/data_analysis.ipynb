# %% [markdown]
# ## Data Processes: Second Assignment (second part)
#
# ### Group:
# Víctor Morcuende Castell, 47315589N
#
# Guillermo Nájera Lavid, 70845359T
#
# Javier Rocamora García, 20081979N
#
# Antonio Ruiz García, 06601574E

# %% [markdown]
# Importing the libraries that will be used:

# %%
# If importing from google colab
    # from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Importing the dataset already cleaned and pre-processed from an excel

# %%
# If importing from google colab
    # drive.mount("/content/gdrive", force_remount=True)
    # df = pd.DataFrame(pd.read_excel("/content/gdrive/MyDrive/output_def.xlsx"))
df = pd.read_excel("output_def.xlsx")
df_preprocessed_def = pd.read_excel("output_def_preprocess.xlsx")

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# Plotting with the different variables in order to see the distribution of the different values and looking on those variables which are of interest

# %% [markdown]
# #### Temporary analysis

# %%
df_preprocessed_def = pd.read_excel("output_def_preprocess.xlsx")

# %%
# Bar plot of sides of the tumours
arr = [[df_preprocessed_def['side_left'].astype(int).sum(),df_preprocessed_def['side_right'].astype(int).sum(),df_preprocessed_def['side_unknown'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['side_left', 'side_right', 'side_unkwnown'])

print(df_aux)
df_aux.plot.bar()


# Bar plot of the grades of the tumours
arr = [[df_preprocessed_def['grade_1.0'].astype(int).sum(),df_preprocessed_def['grade_2.0'].astype(int).sum(),df_preprocessed_def['grade_3.0'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['grade_1.0', 'grade_2.0', 'grade_3.0'])

print(df_aux)
df_aux.plot.bar()


# Bar plot of the hist_type of the tumours
arr = [[df_preprocessed_def['hist_type_ductal'].astype(int).sum(),df_preprocessed_def['hist_type_lobular'].astype(int).sum(),df_preprocessed_def['hist_type_unknown'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['hist_type_ductal', 'hist_type_lobular', 'hist_type_unknown'])

print(df_aux)
df_aux.plot.bar()



# Bar plot of the invasive tumours
arr = [[df_preprocessed_def['invasive'].astype(int).sum(), (df_preprocessed_def['invasive'].shape[0] - df_preprocessed_def['invasive'].astype(int).sum())]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['invasive'],
                   columns = ['YES', 'NO'])

print(df_aux)
df_aux.plot.bar()


# Bar plot of the er_positive, pr_positive
arr = [[df_preprocessed_def['er_positive'].astype(int).sum(), df_preprocessed_def['pr_positive'].astype(int).sum()]]

# converting the array to DF
df_aux = pd.DataFrame(arr,
                   index = ['ehr'],
                   columns = ['er_positive', 'pr_positive'])

print(df_aux)
df_aux.plot.bar()


# Scatter plot of the ki67
df_preprocessed_def['ehr'] = df_preprocessed_def.index
print(df_preprocessed_def.loc[:, ['ki67', 'ehr']])

#df_preprocessed_def.loc[:, ['ki67']].plot()

df_preprocessed_def.loc[:, ['ki67', 'ehr']].plot(kind='scatter',    # kind of plot to show
        x='ehr',
        y='ki67'
       )

# Box plot of the ki67
df_preprocessed_def['ehr'] = df_preprocessed_def.index
print(df_preprocessed_def.loc[:, ['ki67', 'ehr']])

#df_preprocessed_def.loc[:, ['ki67']].plot()

df_preprocessed_def.loc[:, ['ki67', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='ki67'
       )


# Box plot of the ki67
df_preprocessed_def['ehr'] = df_preprocessed_def.index
print(df_preprocessed_def.loc[:, ['ki67', 'ehr']])

df_preprocessed_def.loc[:, ['ki67', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='ki67',
        title='ki67'
       )

# Box plot of the menarche_age, menopause_age
print(df_preprocessed_def.loc[:, ['menopause_age', 'menarche_age', 'ehr']])

df_preprocessed_def.loc[:, ['menopause_age', 'menarche_age', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y=['menarche_age', 'menopause_age'],
        title='menopause_age'
       )

# Pregnancy analysis
df_preprocessed_def.loc[:, ['pregnancy', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='pregnancy',
        title='pregnancy'
       )

# Abort analysis
df_preprocessed_def.loc[:, ['abort', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='abort',
        title='abort'
       )

# Birth analysis
df_preprocessed_def.loc[:, ['birth', 'ehr']].plot(kind='box',    # kind of plot to show
        x='ehr',
        y='birth',
        title='birth'
       )

df_birth = pd.DataFrame(df_preprocessed_def.groupby(['birth'])['ehr'].count())
print(df_birth)

df_birth.plot(kind = 'barh',
         title = 'Birth Horizontal Bar Analysis')

# Caesarean analysis
print(df_preprocessed_def.groupby(['caesarean'])['ehr'].count())
pd.DataFrame(df_preprocessed_def.groupby(['caesarean'])['ehr'].count()).plot(kind = 'barh',
                                                                              title = 'Caesarean Horizontal Bar Analysis')

pd.DataFrame(df_preprocessed_def.groupby(['caesarean'])['ehr'].count()).plot(kind = 'box',
                                                                              title = 'Caesarean Box Analysis')


# 'age_diagnosed' analysis
print(df_preprocessed_def.groupby(['age_diagnosed'])['ehr'].count())
pd.DataFrame(df_preprocessed_def.groupby(['age_diagnosed'])['ehr'].count()).plot(kind = 'barh',
                                                                              title = 'age_diagnosed Horizontal Bar Analysis')

pd.DataFrame(df_preprocessed_def['age_diagnosed']).plot(kind = 'box',
                                                         title = 'age_diagnosed Box Analysis')


age_diagnosed_df = pd.DataFrame(df_preprocessed_def.groupby(['age_diagnosed'])['ehr'].count())
# Out:
#      side_left  side_right  side_unkwnown
# ehr          7           7            233
#      grade_1.0  grade_2.0  grade_3.0
# ehr         46        170         31
#      hist_type_ductal  hist_type_lobular  hist_type_unknown
# ehr               117                 20                104
#           YES  NO
# invasive  213  34
#      er_positive  pr_positive
# ehr          208          183
#           ki67  ehr
# 0    20.465116    0
# 1    20.465116    1
# 2     0.000000    2
# 3    17.000000    3
# 4    44.000000    4
# ..         ...  ...
# 242  20.465116  242
# 243  20.465116  243
# 244  20.465116  244
# 245  20.465116  245
# 246  20.465116  246
#
# [247 rows x 2 columns]
#           ki67  ehr
# 0    20.465116    0
# 1    20.465116    1
# 2     0.000000    2
# 3    17.000000    3
# 4    44.000000    4
# ..         ...  ...
# 242  20.465116  242
# 243  20.465116  243
# 244  20.465116  244
# 245  20.465116  245
# 246  20.465116  246
#
# [247 rows x 2 columns]
#           ki67  ehr
# 0    20.465116    0
# 1    20.465116    1
# 2     0.000000    2
# 3    17.000000    3
# 4    44.000000    4
# ..         ...  ...
# 242  20.465116  242
# 243  20.465116  243
# 244  20.465116  244
# 245  20.465116  245
# 246  20.465116  246
#
# [247 rows x 2 columns]
#      menopause_age  menarche_age  ehr
# 0               51            17    0
# 1               49            12    1
# 2               49            11    2
# 3               49            13    3
# 4               49            14    4
# ..             ...           ...  ...
# 242             49            13  242
# 243             49            13  243
# 244             49            13  244
# 245             49            13  245
# 246             49            13  246
#
# [247 rows x 3 columns]
#        ehr
# birth
# 0      145
# 1       30
# 2       48
# 3       17
# 4        5
# 5        1
# 6        1
# caesarean
# 0    237
# 1      5
# 2      5
# Name: ehr, dtype: int64
# age_diagnosed
# 24     2
# 27     1
# 28     1
# 29     2
# 30     2
#       ..
# 85     1
# 90     1
# 94     1
# 97     1
# 102    1
# Name: ehr, Length: 62, dtype: int64

# %% [markdown]
# - n_tumor analysis

# %%
print(df_preprocessed_def.groupby(['n_tumor'])['ehr'].count())
pd.DataFrame(df_preprocessed_def.groupby(['n_tumor'])['ehr'].count()).plot(kind = 'barh',
                                                                              title = 'n_tumor Horizontal Bar Analysis')

pd.DataFrame(df_preprocessed_def.groupby(['n_tumor'])['ehr'].count()).plot(kind = 'box',
                                                                              title = 'n_tumor Box Analysis')
# Out:
# n_tumor
# 1    245
# 3      2
# Name: ehr, dtype: int64
# <AxesSubplot:title={'center':'n_tumor Box Analysis'}>

# %% [markdown]
# #### Univariate type 'bar' analysis

# %%
print(df.groupby([df['m']])['ehr'].count())
# Out:
# m
# 0          230
# 1           15
# unknown      2
# Name: ehr, dtype: int64

# %%
df_preprocessed_columns_array = df.columns.tolist()

"""
pd.DataFrame(df_preprocessed_def.groupby([df_preprocessed_columns_array[3]])['ehr'].count()).plot(kind = 'barh',
                                                                              title = check + ' si es el')
"""

for i in range (0, df.shape[1]):
    #print(df_preprocessed_def.iloc[:, i])
    pd.DataFrame(df.groupby([df_preprocessed_columns_array[i]])['ehr'].count()).plot(kind = 'bar',
                                                                              title = df_preprocessed_columns_array[i] + ' Horizontal Bar Analysis')
# Out:
# c:\Users\javie\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# #### Univariate type 'box' analysis

# %%
df_preprocessed_columns_array = df.columns.tolist()
print(df_preprocessed_columns_array )

"""
pd.DataFrame(df_preprocessed_def.groupby([df_preprocessed_columns_array[3]])['ehr'].count()).plot(kind = 'barh',
                                                                              title = check + ' si es el')
"""

for i in range (0, df.shape[1]):
    #print(df_preprocessed_def.iloc[:, i])
    pd.DataFrame(df.groupby([df_preprocessed_columns_array[i]])['ehr'].count()).plot(kind = 'box',
                                                                              title = df_preprocessed_columns_array[i] + ' Horizontal Bar Analysis')
# Out:
# ['ehr', 'side', 'neoadjuvant', 'grade', 'invasive', 'er_positive', 'pr_positive', 'her2_positive', 'hist_type', 'ki67', 'menarche_age', 'menopause_age', 'pregnancy', 'abort', 'birth', 'caesarean', 'age_diagnosed', 'survival_time', 'recurrence_time', 'n_tumor', 't', 'n', 'm', 't_after_neoadj', 'n_after_neoadj', 'm_after_neoadj']
# c:\Users\javie\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py:386: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical variables correlation

# %% [markdown]
# First we will see the correlation between the variables with the correlation matrix, to see which of them will be worth to plot

# %%
corr_matrix = df.corr()
corr_matrix.to_excel("corr_matrix.xlsx")
print(corr_matrix)
# Out:
#                       ehr  neoadjuvant     grade  invasive   er_positive  \
# ehr              1.000000    -0.064053 -0.043814  0.030133  7.697534e-02
# neoadjuvant     -0.064053     1.000000  0.255641  0.110352 -9.085324e-02
# grade           -0.043814     0.255641  1.000000 -0.086059 -8.738721e-02
# invasive         0.030133     0.110352 -0.086059  1.000000 -1.085501e-01
# er_positive      0.076975    -0.090853 -0.087387 -0.108550  1.000000e+00
# pr_positive      0.024725    -0.076550 -0.014761  0.005103  2.253983e-01
# her2_positive   -0.001723     0.066123  0.165657 -0.002509 -1.525686e-01
# ki67            -0.113033     0.245781  0.285676 -0.042727 -2.568321e-01
# menarche_age    -0.064785    -0.010450  0.068402 -0.056945  8.717755e-02
# menopause_age    0.041636    -0.085895  0.049071 -0.062399  1.073713e-03
# pregnancy        0.055879    -0.042564 -0.095202  0.024306 -1.266845e-03
# abort            0.012883     0.054385  0.020759  0.005901  5.448977e-18
# birth            0.060787    -0.071415 -0.120270  0.026324 -1.492367e-03
# caesarean       -0.006136    -0.064229 -0.025438  0.077693 -2.245444e-02
# age_diagnosed   -0.102928    -0.021236 -0.100575 -0.042799  9.527012e-03
# survival_time    0.046748    -0.150175 -0.032504  0.096670  3.367510e-02
# recurrence_time -0.073422    -0.026417 -0.063727  0.061213 -6.343026e-02
# n_tumor         -0.008457    -0.044947 -0.071508  0.036098  3.912304e-02
#
#                  pr_positive  her2_positive          ki67  menarche_age  \
# ehr                 0.024725      -0.001723 -1.130325e-01     -0.064785
# neoadjuvant        -0.076550       0.066123  2.457812e-01     -0.010450
# grade              -0.014761       0.165657  2.856763e-01      0.068402
# invasive            0.005103      -0.002509 -4.272656e-02     -0.056945
# er_positive         0.225398      -0.152569 -2.568321e-01      0.087178
# pr_positive         1.000000      -0.020916 -1.900875e-01      0.057329
# her2_positive      -0.020916       1.000000  1.374311e-01      0.026068
# ki67               -0.190088       0.137431  1.000000e+00     -0.017558
# menarche_age        0.057329       0.026068 -1.755812e-02      1.000000
# menopause_age       0.004514       0.039104  2.135620e-02      0.168497
# pregnancy          -0.028440       0.016774  1.896570e-01      0.085706
# abort              -0.123747       0.078644  2.180307e-01      0.071678
# birth               0.014904      -0.011003  1.381321e-01      0.072925
# caesarean           0.026234       0.115856 -6.208292e-02     -0.048929
# age_diagnosed      -0.098378      -0.050291 -1.022098e-01      0.017523
# survival_time       0.095235       0.057771 -1.118034e-01     -0.015668
# recurrence_time    -0.028830       0.044569 -4.775862e-02      0.090623
# n_tumor             0.053431       0.077657  1.311049e-16      0.105938
#
#                  menopause_age  pregnancy         abort     birth  caesarean  \
# ehr                   0.041636   0.055879  1.288281e-02  0.060787  -0.006136
# neoadjuvant          -0.085895  -0.042564  5.438527e-02 -0.071415  -0.064229
# grade                 0.049071  -0.095202  2.075875e-02 -0.120270  -0.025438
# invasive             -0.062399   0.024306  5.901385e-03  0.026324   0.077693
# er_positive           0.001074  -0.001267  5.448977e-18 -0.001492  -0.022454
# pr_positive           0.004514  -0.028440 -1.237475e-01  0.014904   0.026234
# her2_positive         0.039104   0.016774  7.864395e-02 -0.011003   0.115856
# ki67                  0.021356   0.189657  2.180307e-01  0.138132  -0.062083
# menarche_age          0.168497   0.085706  7.167778e-02  0.072925  -0.048929
# menopause_age         1.000000  -0.045754 -6.434004e-03 -0.051383  -0.103093
# pregnancy            -0.045754   1.000000  5.867344e-01  0.948505   0.000569
# abort                -0.006434   0.586734  1.000000e+00  0.300013  -0.008681
# birth                -0.051383   0.948505  3.000131e-01  1.000000   0.004066
# caesarean            -0.103093   0.000569 -8.680874e-03  0.004066   1.000000
# age_diagnosed         0.082281   0.169350 -6.781400e-03  0.202150  -0.119691
# survival_time         0.061888  -0.097625 -6.224923e-02 -0.090654   0.009965
# recurrence_time       0.130224   0.008369  2.033098e-02  0.001906  -0.004096
# n_tumor               0.029573   0.065555 -3.024990e-02  0.089058  -0.017570
#
#                  age_diagnosed  survival_time  recurrence_time       n_tumor
# ehr                  -0.102928       0.046748        -0.073422 -8.456728e-03
# neoadjuvant          -0.021236      -0.150175        -0.026417 -4.494666e-02
# grade                -0.100575      -0.032504        -0.063727 -7.150758e-02
# invasive             -0.042799       0.096670         0.061213  3.609787e-02
# er_positive           0.009527       0.033675        -0.063430  3.912304e-02
# pr_positive          -0.098378       0.095235        -0.028830  5.343138e-02
# her2_positive        -0.050291       0.057771         0.044569  7.765663e-02
# ki67                 -0.102210      -0.111803        -0.047759  1.311049e-16
# menarche_age          0.017523      -0.015668         0.090623  1.059383e-01
# menopause_age         0.082281       0.061888         0.130224  2.957287e-02
# pregnancy             0.169350      -0.097625         0.008369  6.555509e-02
# abort                -0.006781      -0.062249         0.020331 -3.024990e-02
# birth                 0.202150      -0.090654         0.001906  8.905799e-02
# caesarean            -0.119691       0.009965        -0.004096 -1.756972e-02
# age_diagnosed         1.000000      -0.174980         0.077865  2.362409e-02
# survival_time        -0.174980       1.000000         0.381037  2.681808e-02
# recurrence_time       0.077865       0.381037         1.000000  3.422772e-02
# n_tumor               0.023624       0.026818         0.034228  1.000000e+00

# %%
def numerical_relation(var1,var2):
  data1 = df[var1]
  data2 = df[var2]
  plt.plot(data1,data2,"bo")
  plt.xlabel(var1)
  plt.ylabel(var2)
  plt.show()

# Relation between age of diagnose and other variables
numerical_relation('menarche_age','age_diagnosed')
numerical_relation('menopause_age','age_diagnosed')
numerical_relation('pregnancy','age_diagnosed')
numerical_relation('abort','age_diagnosed')
numerical_relation('birth','age_diagnosed')

# %% [markdown]
# ### Categorical variables correlation

# %%
from statsmodels.graphics.mosaicplot import mosaic

# Labelizer contiene el numero de datos que contiene ambas etiquetas (Se ve en crosstable)
def categorical_relation(var1,var2,labelizer):
  crosstable=pd.crosstab(df[var1],df[var2])
  print(crosstable)
  labelizer= labelizer
  mosaic(df,[var1,var2],gap=0.01, title='Relation between ' + var1 + ' and ' + var2,horizontal = False,labelizer = labelizer)

categorical_relation('neoadjuvant','grade',
                      lambda k:{('0','1'):44  ,('0','2'):136  ,('0','3'):18,('1','1'):2,('1','2'):34,('1','3'):13}[k])
# Out:
# grade         1    2   3
# neoadjuvant
# 0            44  136  18
# 1             2   34  13

# %% [markdown]
# ### Categorical and numerical variables correlation

# %% [markdown]
# First we will see the correlation between the variables with the correlation matrix, to see which of them will be worth to plot

# %%
corr_matrix = df_preprocessed_def.corr()
corr_matrix.to_excel("corr_matrix_preprocessed.xlsx")
print(corr_matrix)
# Out:
#                              ehr  side_left  side_right  side_unknown  \
# ehr                     1.000000   0.054405   -0.005475     -0.035115
# side_left               0.054405   1.000000   -0.029167     -0.696718
# side_right             -0.005475  -0.029167    1.000000     -0.696718
# side_unknown           -0.035115  -0.696718   -0.696718      1.000000
# grade_1.0              -0.050174  -0.019030   -0.081700      0.072289
# grade_2.0               0.024394   0.062267    0.062267     -0.089372
# grade_3.0               0.024852  -0.064699    0.008945      0.040012
# hist_type_ductal       -0.091885  -0.015430   -0.064293      0.057213
# hist_type_lobular       0.026851  -0.050693    0.038744      0.008575
# hist_type_unknown      -0.005060   0.052016    0.052016     -0.074658
# neoadjuvant             0.010821  -0.023779   -0.023779      0.034129
# invasive               -0.022908  -0.144206   -0.215019      0.257798
# er_positive            -0.011834  -0.059865   -0.059865      0.085924
# pr_positive            -0.036934   0.045313   -0.066054      0.014884
# her2_positive          -0.086252  -0.014067   -0.078408      0.066365
# ki67                    0.073076   0.045101   -0.010476     -0.024848
# menarche_age           -0.025174  -0.013352   -0.013352      0.019164
# menopause_age           0.017197  -0.048700   -0.003872      0.037728
# pregnancy              -0.121167   0.018130    0.000500     -0.013370
# abort                  -0.031881  -0.004084   -0.057179      0.043965
# birth                  -0.130266   0.022955    0.022955     -0.032948
# caesarean               0.050364   0.044913    0.123037     -0.120530
# age_diagnosed          -0.140040   0.001977   -0.050944      0.035141
# survival_time          -0.066985  -0.217302   -0.038369      0.183483
# recurrence_time        -0.086022  -0.227920   -0.081871      0.222321
# n_tumor                -0.155226  -0.015430   -0.015430      0.022147
# t_0                    -0.035003  -0.071686   -0.071686      0.102891
# t_1                    -0.002994  -0.144438   -0.045475      0.136291
# t_2                     0.053090   0.084521    0.025879     -0.079228
# t_3                     0.104321   0.188367    0.074887     -0.188924
# t_4                     0.117707   0.117857   -0.029167     -0.063649
# t_IS                   -0.060210  -0.044947    0.153300     -0.077760
# t_X                     0.101938  -0.010889   -0.010889      0.015629
# t_unknown              -0.000634  -0.015430   -0.015430      0.022147
# n_0                    -0.150919  -0.092415    0.054853      0.026956
# n_1                     0.063377   0.000877   -0.053262      0.037594
# n_2                     0.099305   0.108719    0.026346     -0.096929
# n_3                    -0.018167   0.081403   -0.036871     -0.031959
# n_X                     0.101938  -0.010889   -0.010889      0.015629
# n_unknown               0.113361  -0.021911   -0.021911      0.031449
# m_0                    -0.042839  -0.242687    0.046431      0.140844
# m_1                     0.072512   0.263035   -0.043426     -0.157602
# m_unknown              -0.072228  -0.015430   -0.015430      0.022147
# t_after_neoadj_0       -0.071213  -0.047881   -0.047881      0.068723
# t_after_neoadj_1       -0.094536  -0.135526   -0.086586      0.159399
# t_after_neoadj_2        0.082649   0.135620    0.020506     -0.112044
# t_after_neoadj_3        0.098268   0.081403    0.081403     -0.116838
# t_after_neoadj_4        0.117707   0.117857   -0.029167     -0.063649
# t_after_neoadj_IS      -0.061680  -0.046431    0.146315     -0.071682
# t_after_neoadj_X        0.101938  -0.010889   -0.010889      0.015629
# t_after_neoadj_unknown -0.000634  -0.015430   -0.015430      0.022147
# n_after_neoadj_0       -0.182218  -0.110844    0.038765      0.051727
# n_after_neoadj_1        0.073479   0.010370   -0.045313      0.025077
# n_after_neoadj_2        0.107404   0.128180    0.038744     -0.119793
# n_after_neoadj_3        0.036667   0.096996   -0.033211     -0.045776
# n_after_neoadj_X        0.101938  -0.010889   -0.010889      0.015629
# n_after_neoadj_unknown  0.113361  -0.021911   -0.021911      0.031449
# m_after_neoadj_0       -0.078931  -0.263035    0.043426      0.157602
# m_after_neoadj_1        0.113410   0.287527   -0.040254     -0.177456
# m_after_neoadj_unknown -0.072228  -0.015430   -0.015430      0.022147
#
#                         grade_1.0  grade_2.0  grade_3.0  hist_type_ductal  \
# ehr                     -0.050174   0.024394   0.024852         -0.091885
# side_left               -0.019030   0.062267  -0.064699         -0.015430
# side_right              -0.081700   0.062267   0.008945         -0.064293
# side_unknown             0.072289  -0.089372   0.040012          0.057213
# grade_1.0                1.000000  -0.710821  -0.181232         -0.078929
# grade_2.0               -0.710821   1.000000  -0.562902         -0.026718
# grade_3.0               -0.181232  -0.562902   1.000000          0.130105
# hist_type_ductal        -0.078929  -0.026718   0.130105          1.000000
# hist_type_lobular       -0.065751   0.071605  -0.022853         -0.281594
# hist_type_unknown        0.139686  -0.045655  -0.100309         -0.809040
# neoadjuvant             -0.185825   0.006034   0.209924         -0.004281
# invasive                 0.130761  -0.116675   0.009478          0.120149
# er_positive              0.007505   0.092094  -0.137583          0.032770
# pr_positive             -0.049394   0.100712  -0.082771          0.024350
# her2_positive           -0.055075  -0.105920   0.212812          0.077657
# ki67                    -0.191249  -0.020839   0.253870          0.113504
# menarche_age            -0.058212   0.015887   0.046192         -0.031982
# menopause_age           -0.053612   0.031317   0.019212         -0.007319
# pregnancy                0.084067  -0.027233  -0.060709          0.002776
# abort                   -0.001741  -0.021947   0.032732          0.052937
# birth                    0.099714  -0.023496  -0.084320         -0.017438
# caesarean                0.040177  -0.037053   0.004594          0.049195
# age_diagnosed            0.070509   0.001996  -0.085644         -0.106543
# survival_time            0.027491  -0.007262  -0.022151         -0.074917
# recurrence_time          0.055769  -0.017381  -0.041231         -0.105772
# n_tumor                  0.072821  -0.036721  -0.034228          0.004762
# t_0                     -0.113380  -0.060386   0.217661         -0.011958
# t_1                      0.228171  -0.086696  -0.146904         -0.062318
# t_2                     -0.106060   0.108104  -0.026519          0.057443
# t_3                     -0.011359   0.030120  -0.028766          0.049624
# t_4                     -0.081700   0.114938  -0.064699         -0.113156
# t_IS                    -0.083650   0.070590  -0.000402          0.046814
# t_X                     -0.030501   0.042909  -0.024154         -0.060486
# t_unknown                0.072821  -0.036721  -0.034228          0.004762
# n_0                      0.114790  -0.093057  -0.004778          0.034346
# n_1                     -0.070073   0.074125  -0.021299          0.033144
# n_2                     -0.051603   0.043727  -0.000501         -0.037462
# n_3                     -0.103281   0.060555   0.036697         -0.047583
# n_X                     -0.030501   0.042909  -0.024154         -0.060486
# n_unknown                0.103407  -0.121391   0.048213         -0.057477
# m_0                     -0.034261   0.024182   0.006449          0.065744
# m_1                      0.008991   0.024743  -0.045161         -0.071474
# m_unknown                0.072821  -0.134249   0.102133          0.004762
# t_after_neoadj_0        -0.014093  -0.046695   0.081848         -0.047613
# t_after_neoadj_1         0.171705  -0.149702   0.007543         -0.016265
# t_after_neoadj_2        -0.117805   0.125388  -0.036884          0.048325
# t_after_neoadj_3        -0.002449   0.018184  -0.022546          0.031033
# t_after_neoadj_4        -0.081700   0.114938  -0.064699         -0.113156
# t_after_neoadj_IS       -0.088979   0.044869   0.041823          0.062372
# t_after_neoadj_X        -0.030501   0.042909  -0.024154         -0.060486
# t_after_neoadj_unknown   0.072821  -0.036721  -0.034228          0.004762
# n_after_neoadj_0         0.069109  -0.099166   0.057443          0.006979
# n_after_neoadj_1        -0.045550   0.078825  -0.056687          0.049674
# n_after_neoadj_2        -0.027628   0.039564  -0.022853         -0.014080
# n_after_neoadj_3        -0.093028   0.084228  -0.008450         -0.054661
# n_after_neoadj_X        -0.030501   0.042909  -0.024154         -0.060486
# n_after_neoadj_unknown   0.103407  -0.121391   0.048213         -0.057477
# m_after_neoadj_0        -0.052535   0.011853   0.045161          0.071474
# m_after_neoadj_1         0.026964   0.041203  -0.089293         -0.078358
# m_after_neoadj_unknown   0.072821  -0.134249   0.102133          0.004762
#
#                         hist_type_lobular  hist_type_unknown  ...  \
# ehr                              0.026851          -0.005060  ...
# side_left                       -0.050693           0.052016  ...
# side_right                       0.038744           0.052016  ...
# side_unknown                     0.008575          -0.074658  ...
# grade_1.0                       -0.065751           0.139686  ...
# grade_2.0                        0.071605          -0.045655  ...
# grade_3.0                       -0.022853          -0.100309  ...
# hist_type_ductal                -0.281594          -0.809040  ...
# hist_type_lobular                1.000000          -0.253134  ...
# hist_type_unknown               -0.253134           1.000000  ...
# neoadjuvant                      0.001205           0.028139  ...
# invasive                         0.118591          -0.206687  ...
# er_positive                     -0.074976          -0.013019  ...
# pr_positive                      0.073917          -0.094562  ...
# her2_positive                   -0.057997          -0.023902  ...
# ki67                            -0.128601          -0.043733  ...
# menarche_age                    -0.119729           0.092497  ...
# menopause_age                   -0.011924           0.012952  ...
# pregnancy                        0.075942          -0.009356  ...
# abort                            0.029814          -0.053536  ...
# birth                            0.077799           0.009920  ...
# caesarean                        0.037326          -0.060807  ...
# age_diagnosed                    0.032957           0.111099  ...
# survival_time                    0.088104           0.012481  ...
# recurrence_time                  0.067303           0.051143  ...
# n_tumor                         -0.026818           0.014447  ...
# t_0                              0.041755          -0.013303  ...
# t_1                             -0.130637           0.110288  ...
# t_2                              0.126516          -0.121370  ...
# t_3                              0.001956          -0.040148  ...
# t_4                              0.038744           0.101431  ...
# t_IS                            -0.078119           0.008767  ...
# t_X                             -0.018925           0.074762  ...
# t_unknown                        0.138786          -0.077051  ...
# n_0                             -0.062504           0.038208  ...
# n_1                             -0.022000          -0.081403  ...
# n_2                              0.052949           0.024771  ...
# n_3                              0.151760          -0.025107  ...
# n_X                             -0.018925           0.074762  ...
# n_unknown                       -0.038083           0.085480  ...
# m_0                              0.080698          -0.124449  ...
# m_1                             -0.075475           0.126493  ...
# m_unknown                       -0.026818           0.014447  ...
# t_after_neoadj_0                 0.030976          -0.018264  ...
# t_after_neoadj_1                -0.141984           0.098693  ...
# t_after_neoadj_2                 0.150682          -0.124215  ...
# t_after_neoadj_3                 0.007865          -0.025107  ...
# t_after_neoadj_4                 0.038744           0.101431  ...
# t_after_neoadj_IS               -0.080698          -0.005114  ...
# t_after_neoadj_X                -0.018925           0.074762  ...
# t_after_neoadj_unknown           0.138786          -0.077051  ...
# n_after_neoadj_0                -0.062638           0.071456  ...
# n_after_neoadj_1                -0.040044          -0.092591  ...
# n_after_neoadj_2                 0.129515          -0.042716  ...
# n_after_neoadj_3                 0.100691           0.009213  ...
# n_after_neoadj_X                -0.018925           0.074762  ...
# n_after_neoadj_unknown          -0.038083           0.085480  ...
# m_after_neoadj_0                 0.075475          -0.126493  ...
# m_after_neoadj_1                -0.069963           0.129495  ...
# m_after_neoadj_unknown          -0.026818           0.014447  ...
#
#                         t_after_neoadj_unknown  n_after_neoadj_0  \
# ehr                              -6.335767e-04         -0.182218
# side_left                        -1.543033e-02         -0.110844
# side_right                       -1.543033e-02          0.038765
# side_unknown                      2.214716e-02          0.051727
# grade_1.0                         7.282101e-02          0.069109
# grade_2.0                        -3.672105e-02         -0.099166
# grade_3.0                        -3.422835e-02          0.057443
# hist_type_ductal                  4.761905e-03          0.006979
# hist_type_lobular                 1.387856e-01         -0.062638
# hist_type_unknown                -7.705141e-02          0.071456
# neoadjuvant                       6.833726e-02         -0.198362
# invasive                          3.609787e-02         -0.035786
# er_positive                       3.912304e-02         -0.124224
# pr_positive                      -4.967449e-02         -0.045192
# her2_positive                     7.765663e-02         -0.020499
# ki67                             -2.695742e-19          0.018767
# menarche_age                      4.265715e-02         -0.029333
# menopause_age                    -1.226042e-01         -0.006956
# pregnancy                         2.614274e-01         -0.014333
# abort                             6.806227e-02         -0.016624
# birth                             2.813423e-01         -0.010382
# caesarean                        -1.756972e-02          0.025212
# age_diagnosed                     7.736057e-02          0.015512
# survival_time                    -1.395931e-01          0.214614
# recurrence_time                   3.422772e-02          0.167568
# n_tumor                          -8.163265e-03          0.073274
# t_0                              -3.792479e-02         -0.076983
# t_1                              -7.641336e-02          0.182380
# t_2                              -4.835737e-02         -0.182563
# t_3                              -2.041685e-02         -0.201652
# t_4                              -1.543033e-02         -0.160713
# t_IS                             -2.377858e-02          0.213439
# t_X                              -5.760556e-03         -0.078616
# t_unknown                         1.000000e+00         -0.111407
# n_0                              -1.008314e-01          0.905073
# n_1                               4.342603e-02         -0.665249
# n_2                              -2.964047e-02         -0.264812
# n_3                              -1.950618e-02         -0.226090
# n_X                              -5.760556e-03         -0.078616
# n_unknown                         3.463114e-01         -0.158200
# m_0                              -1.538839e-01          0.302539
# m_1                               1.661774e-01         -0.313532
# m_unknown                        -8.163265e-03         -0.019066
# t_after_neoadj_0                 -2.533089e-02         -0.027326
# t_after_neoadj_1                 -9.759001e-02          0.228572
# t_after_neoadj_2                 -5.005126e-02         -0.194993
# t_after_neoadj_3                 -1.950618e-02         -0.185972
# t_after_neoadj_4                 -1.543033e-02         -0.160713
# t_after_neoadj_IS                -2.456363e-02          0.220486
# t_after_neoadj_X                 -5.760556e-03         -0.078616
# t_after_neoadj_unknown            1.000000e+00         -0.111407
# n_after_neoadj_0                 -1.114069e-01          1.000000
# n_after_neoadj_1                  4.967449e-02         -0.729196
# n_after_neoadj_2                 -2.681847e-02         -0.366001
# n_after_neoadj_3                 -1.756972e-02         -0.239780
# n_after_neoadj_X                 -5.760556e-03         -0.078616
# n_after_neoadj_unknown            3.463114e-01         -0.158200
# m_after_neoadj_0                 -1.661774e-01          0.278882
# m_after_neoadj_1                  1.810150e-01         -0.290632
# m_after_neoadj_unknown           -8.163265e-03         -0.019066
#
#                         n_after_neoadj_1  n_after_neoadj_2  n_after_neoadj_3  \
# ehr                             0.073479          0.107404          0.036667
# side_left                       0.010370          0.128180          0.096996
# side_right                     -0.045313          0.038744         -0.033211
# side_unknown                    0.025077         -0.119793         -0.045776
# grade_1.0                      -0.045550         -0.027628         -0.093028
# grade_2.0                       0.078825          0.039564          0.084228
# grade_3.0                      -0.056687         -0.022853         -0.008450
# hist_type_ductal                0.049674         -0.014080         -0.054661
# hist_type_lobular              -0.040044          0.129515          0.100691
# hist_type_unknown              -0.092591         -0.042716          0.009213
# neoadjuvant                     0.007036          0.224506          0.174173
# invasive                        0.102175         -0.010638          0.014980
# er_positive                     0.053349          0.087828          0.024949
# pr_positive                     0.012295          0.040044          0.065686
# her2_positive                   0.020916         -0.018857         -0.032298
# ki67                           -0.068823          0.035256          0.043559
# menarche_age                    0.117410         -0.109334         -0.067089
# menopause_age                   0.029443         -0.052828          0.076883
# pregnancy                       0.015085         -0.042031          0.047410
# abort                           0.083530         -0.034783         -0.065107
# birth                          -0.014904         -0.035907          0.081318
# caesarean                      -0.055823          0.037326          0.031373
# age_diagnosed                  -0.063260         -0.045966          0.050846
# survival_time                  -0.028422         -0.128439         -0.101065
# recurrence_time                -0.027693         -0.156115         -0.056135
# n_tumor                        -0.053431         -0.026818         -0.017570
# t_0                             0.036585          0.000168          0.100009
# t_1                             0.005842         -0.190838         -0.164464
# t_2                             0.105475          0.162188         -0.000210
# t_3                             0.038281          0.140018          0.257555
# t_4                             0.010370          0.217617          0.096996
# t_IS                           -0.155639         -0.078119         -0.051178
# t_X                            -0.037705         -0.018925         -0.012398
# t_unknown                       0.049674         -0.026818         -0.017570
# n_0                            -0.659976         -0.331258         -0.217018
# n_1                             0.899368         -0.120799         -0.122291
# n_2                            -0.162809          0.754467          0.009156
# n_3                            -0.082880          0.007865          0.795980
# n_X                            -0.037705         -0.018925         -0.012398
# n_unknown                      -0.075874         -0.038083         -0.024949
# m_0                            -0.021723         -0.271050         -0.203179
# m_1                             0.004386          0.297372          0.221959
# m_unknown                       0.049674         -0.026818         -0.017570
# t_after_neoadj_0                0.011946         -0.026121          0.028606
# t_after_neoadj_1               -0.027090         -0.201526         -0.166700
# t_after_neoadj_2                0.086578          0.185694          0.045195
# t_after_neoadj_3                0.051505          0.079812          0.272253
# t_after_neoadj_4                0.010370          0.217617          0.096996
# t_after_neoadj_IS              -0.160777         -0.080698         -0.052868
# t_after_neoadj_X               -0.037705         -0.018925         -0.012398
# t_after_neoadj_unknown          0.049674         -0.026818         -0.017570
# n_after_neoadj_0               -0.729196         -0.366001         -0.239780
# n_after_neoadj_1                1.000000         -0.175536         -0.115000
# n_after_neoadj_2               -0.175536          1.000000         -0.057721
# n_after_neoadj_3               -0.115000         -0.057721          1.000000
# n_after_neoadj_X               -0.037705         -0.018925         -0.012398
# n_after_neoadj_unknown         -0.075874         -0.038083         -0.024949
# m_after_neoadj_0               -0.004386         -0.235231         -0.221959
# m_after_neoadj_1               -0.015246          0.262360          0.244453
# m_after_neoadj_unknown          0.049674         -0.026818         -0.017570
#
#                         n_after_neoadj_X  n_after_neoadj_unknown  \
# ehr                         1.019376e-01                0.113361
# side_left                  -1.088870e-02               -0.021911
# side_right                 -1.088870e-02               -0.021911
# side_unknown                1.562854e-02                0.031449
# grade_1.0                  -3.050095e-02                0.103407
# grade_2.0                   4.290949e-02               -0.121391
# grade_3.0                  -2.415385e-02                0.048213
# hist_type_ductal           -6.048584e-02               -0.057477
# hist_type_lobular          -1.892494e-02               -0.038083
# hist_type_unknown           7.476250e-02                0.085480
# neoadjuvant                -3.171742e-02                0.016608
# invasive                   -1.595816e-01               -0.134934
# er_positive                 2.760788e-02                0.055556
# pr_positive                 3.770482e-02               -0.070539
# her2_positive              -2.927195e-02                0.110274
# ki67                       -3.220009e-17                0.025305
# menarche_age                7.774037e-03                0.038109
# menopause_age               1.343814e-03               -0.075876
# pregnancy                  -4.588707e-02                0.046733
# abort                      -2.134639e-02               -0.042956
# birth                      -4.570573e-02                0.071855
# caesarean                  -1.239839e-02               -0.024949
# age_diagnosed              -4.132471e-02                0.204115
# survival_time               1.892466e-02               -0.315075
# recurrence_time            -1.672625e-01               -0.048473
# n_tumor                    -5.760556e-03               -0.011592
# t_0                        -2.676231e-02                0.036024
# t_1                        -5.392247e-02               -0.043456
# t_2                        -3.412425e-02                0.008427
# t_3                        -1.440752e-02               -0.028992
# t_4                        -1.088870e-02               -0.021911
# t_IS                       -1.677979e-02               -0.033766
# t_X                         1.000000e+00               -0.008180
# t_unknown                  -5.760556e-03                0.346311
# n_0                        -7.115352e-02               -0.143183
# n_1                        -4.009543e-02               -0.080684
# n_2                        -2.091634e-02               -0.042090
# n_3                        -1.376489e-02               -0.027699
# n_X                         1.000000e+00               -0.008180
# n_unknown                  -8.180113e-03                1.000000
# m_0                        -2.345157e-01               -0.091819
# m_1                         2.507441e-01                0.101676
# m_unknown                  -5.760556e-03               -0.011592
# t_after_neoadj_0           -1.787520e-02                0.087428
# t_after_neoadj_1           -6.886616e-02               -0.074239
# t_after_neoadj_2           -3.531958e-02                0.004595
# t_after_neoadj_3           -1.376489e-02               -0.027699
# t_after_neoadj_4           -1.088870e-02               -0.021911
# t_after_neoadj_IS          -1.733377e-02               -0.034881
# t_after_neoadj_X            1.000000e+00               -0.008180
# t_after_neoadj_unknown     -5.760556e-03                0.346311
# n_after_neoadj_0           -7.861629e-02               -0.158200
# n_after_neoadj_1           -3.770482e-02               -0.075874
# n_after_neoadj_2           -1.892494e-02               -0.038083
# n_after_neoadj_3           -1.239839e-02               -0.024949
# n_after_neoadj_X            1.000000e+00               -0.008180
# n_after_neoadj_unknown     -8.180113e-03                1.000000
# m_after_neoadj_0           -2.507441e-01               -0.101676
# m_after_neoadj_1            2.705009e-01                0.113402
# m_after_neoadj_unknown     -5.760556e-03               -0.011592
#
#                         m_after_neoadj_0  m_after_neoadj_1  \
# ehr                            -0.078931          0.113410
# side_left                      -0.263035          0.287527
# side_right                      0.043426         -0.040254
# side_unknown                    0.157602         -0.177456
# grade_1.0                      -0.052535          0.026964
# grade_2.0                       0.011853          0.041203
# grade_3.0                       0.045161         -0.089293
# hist_type_ductal                0.071474         -0.078358
# hist_type_lobular               0.075475         -0.069963
# hist_type_unknown              -0.126493          0.129495
# neoadjuvant                    -0.043541          0.064610
# invasive                        0.144417         -0.168952
# er_positive                    -0.017127          0.052340
# pr_positive                    -0.034304          0.056627
# her2_positive                   0.027330         -0.012583
# ki67                           -0.017272          0.030877
# menarche_age                   -0.007258          0.016041
# menopause_age                  -0.000168         -0.000584
# pregnancy                      -0.037493          0.053098
# abort                           0.048242         -0.039457
# birth                          -0.063039          0.077985
# caesarean                      -0.004835          0.012223
# age_diagnosed                  -0.141211          0.118718
# survival_time                   0.297938         -0.329429
# recurrence_time                 0.107914         -0.129159
# n_tumor                         0.022974         -0.021296
# t_0                             0.011731          0.002674
# t_1                             0.146290         -0.199343
# t_2                            -0.026888          0.048167
# t_3                            -0.100234          0.115402
# t_4                            -0.263035          0.287527
# t_IS                            0.066920         -0.062032
# t_X                            -0.250744          0.270501
# t_unknown                      -0.166177          0.181015
# n_0                             0.249662         -0.263044
# n_1                             0.009442         -0.027528
# n_2                            -0.202750          0.228752
# n_3                            -0.191638          0.212799
# n_X                            -0.250744          0.270501
# n_unknown                      -0.101676          0.113402
# m_0                             0.935279         -0.866968
# m_1                            -0.858046          0.926962
# m_unknown                      -0.355329         -0.021296
# t_after_neoadj_0               -0.059143          0.073424
# t_after_neoadj_1                0.206639         -0.254588
# t_after_neoadj_2               -0.019105          0.040522
# t_after_neoadj_3               -0.109460          0.124904
# t_after_neoadj_4               -0.263035          0.287527
# t_after_neoadj_IS               0.069129         -0.064080
# t_after_neoadj_X               -0.250744          0.270501
# t_after_neoadj_unknown         -0.166177          0.181015
# n_after_neoadj_0                0.278882         -0.290632
# n_after_neoadj_1               -0.004386         -0.015246
# n_after_neoadj_2               -0.235231          0.262360
# n_after_neoadj_3               -0.221959          0.244453
# n_after_neoadj_X               -0.250744          0.270501
# n_after_neoadj_unknown         -0.101676          0.113402
# m_after_neoadj_0                1.000000         -0.926962
# m_after_neoadj_1               -0.926962          1.000000
# m_after_neoadj_unknown         -0.355329         -0.021296
#
#                         m_after_neoadj_unknown
# ehr                                  -0.072228
# side_left                            -0.015430
# side_right                           -0.015430
# side_unknown                          0.022147
# grade_1.0                             0.072821
# grade_2.0                            -0.134249
# grade_3.0                             0.102133
# hist_type_ductal                      0.004762
# hist_type_lobular                    -0.026818
# hist_type_unknown                     0.014447
# neoadjuvant                          -0.044947
# invasive                              0.036098
# er_positive                          -0.084767
# pr_positive                          -0.049674
# her2_positive                        -0.041481
# ki67                                 -0.030905
# menarche_age                         -0.020624
# menopause_age                         0.001904
# pregnancy                            -0.032381
# abort                                -0.030250
# birth                                -0.026313
# caesarean                            -0.017570
# age_diagnosed                         0.080522
# survival_time                         0.026818
# recurrence_time                       0.034228
# n_tumor                              -0.008163
# t_0                                  -0.037925
# t_1                                   0.106830
# t_2                                  -0.048357
# t_3                                  -0.020417
# t_4                                  -0.015430
# t_IS                                 -0.023779
# t_X                                  -0.005761
# t_unknown                            -0.008163
# n_0                                  -0.009936
# n_1                                   0.043426
# n_2                                  -0.029640
# n_3                                  -0.019506
# n_X                                  -0.005761
# n_unknown                            -0.011592
# m_0                                  -0.332331
# m_1                                  -0.022974
# m_unknown                             1.000000
# t_after_neoadj_0                     -0.025331
# t_after_neoadj_1                      0.083649
# t_after_neoadj_2                     -0.050051
# t_after_neoadj_3                     -0.019506
# t_after_neoadj_4                     -0.015430
# t_after_neoadj_IS                    -0.024564
# t_after_neoadj_X                     -0.005761
# t_after_neoadj_unknown               -0.008163
# n_after_neoadj_0                     -0.019066
# n_after_neoadj_1                      0.049674
# n_after_neoadj_2                     -0.026818
# n_after_neoadj_3                     -0.017570
# n_after_neoadj_X                     -0.005761
# n_after_neoadj_unknown               -0.011592
# m_after_neoadj_0                     -0.355329
# m_after_neoadj_1                     -0.021296
# m_after_neoadj_unknown                1.000000
#
# [60 rows x 60 columns]

# %%
# 'age_diagnosed' analysis
print(df.groupby(['grade'])['invasive'].count())

pd.DataFrame(df.groupby(['grade'])['invasive'].count()).plot(kind = 'bar',
                                                                              title = 'grade and invasive Horizontal Bar Analysis')
# Out:
# grade
# 1     46
# 2    170
# 3     31
# Name: invasive, dtype: int64
# <AxesSubplot:title={'center':'grade and invasive Horizontal Bar Analysis'}, xlabel='grade'>

# %%
# 'neoadjuvant' and 'ki67' analysis  
print(df.loc[:, ['ki67']][df['neoadjuvant'] == 0].mean())
print(df.loc[:, ['ki67']][df['neoadjuvant'] == 1].mean())

plt.scatter(df.loc[:, ['ki67']][df['neoadjuvant'] == 1].index, df.loc[:, ['ki67']][df['neoadjuvant'] == 1], label='Neoadjuvant')
plt.scatter(df.loc[:, ['ki67']][df['neoadjuvant'] == 0].index, df.loc[:, ['ki67']][df['neoadjuvant'] == 0], label='No Neoadjuvant')

plt.title('Neoadjuvant and ki67')
plt.xlabel('ehr')
plt.ylabel('ki67')
plt.legend()
plt.show()
# Out:
# ki67    18.511628
# dtype: float64
# ki67    28.358804
# dtype: float64

# %%
def boxplot(categorical, numerical):
  data = []
  for type in (df[categorical]).unique():
    aux = []
    for i in range(len(df['ehr'])):
      if df[categorical][i] == type:
        aux.append(df[numerical][i])
    data.append(aux)

  plt.boxplot(data, vert = False, labels = df[categorical].unique())
  plt.title("Relation between " + numerical +" and "+ categorical)
  plt.show()

boxplot('hist_type','ki67')
boxplot('hist_type','age_diagnosed')
boxplot('hist_type','abort')
boxplot('grade','ki67')
